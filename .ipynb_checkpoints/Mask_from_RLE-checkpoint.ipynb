# %% [markdown]
# ## Generating Masks from the Run-Length Encodings
# Code taken from utility notebooks

# %% [markdown]
# # Converting Run-length Encodings to Pixel Masks
# By Leah Scherschel - Indiana University

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import skimage.io as io

# %% [markdown]
# ## Convert the encoding to a pixel mask

# %%
def rle2mask(mask_rle, shape): 
    '''
    mask_rle: run-length as string format (start length)
    shape: (width,height) of array to return 
    Returns numpy array, 1 - mask, 0 - background

    '''
    s = mask_rle
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T

# %% [markdown]
# ### Train masks

# %%
image_shape=(4536, 4704) #(height, width)

path_to_train_csv = "Colonic_crypt_dataset/train.csv"
mask_save_path = "Colonic_crypt_dataset/train_mask/"
train_csv = pd.read_csv(path_to_train_csv)

for row in train_csv.iterrows():
    rle = row[1][1]
    img_id = row[1][1]
    mask = rle2mask(rle.split(), (image_shape[1], image_shape[0]))
    io.imsave(mask_save_path+"/"+img_id+".tiff")
    plt.imshow(mask)
    plt.show()

# %% [markdown]
# ### Test masks

# %%
image_shape=(4536, 4704) #(height, width)

path_to_train_csv = "Colonic_crypt_dataset/test.csv"
mask_save_path = "Colonic_crypt_dataset/test_mask/"
test_csv = pd.read_csv(path_to_train_csv)

for row in test_csv.iterrows():
    rle = row[1][1]
    img_id = row[1][1]
    mask = rle2mask(rle.split(), (image_shape[1], image_shape[0]))
    io.imsave(mask_save_path+"/"+img_id+".tiff")
    plt.imshow(mask)
    plt.show()
